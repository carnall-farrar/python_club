# %% [markdown]
# # Processing referrals dataset
#
# Tasks:
# * Format weeks as single datetime values, rather than week range
# * Rename columns for convenience
# * Remove referrals from organisations other than CCGs
# * Account for the merging of CCGs in 2020, by mapping 2019 CCG codes to their 2020 equivalents
# * Eliminate clinic_type field, i.e. group by other fields and sum
# * Remove CCG namec column

# %%
# Importing Python packages we are likely to need
import pandas as pd  # data tables
import numpy as np  # numerical operations
import os

ROOT_DIR = "~/cf/coding_club/python_club"
DATA_DIR = os.path.join(ROOT_DIR, 'data')
OUT_DIR = os.path.join(ROOT_DIR, 'outputs')
# CCG_STP_REG_MAP_FILE = os.path.join(DATA_DIR, f'Clinical_Commissioning_Group_to_STP_and_NHS_England_(Region)_(April_2020)_Lookup_in_England.csv')
WRITE = False
REFS_FILE = "referrals.cat.oct19_dec20.csv"
REFS_PATH = os.path.join(DATA_DIR, REFS_FILE)

# %%
ccg_mergers = pd.read_csv(os.path.join(DATA_DIR, "ccg_mergers_2019_2020.csv")).drop(columns=["Legacy (closing) CCG Name", "New CCG Name"])
ccg_19 = pd.read_csv(os.path.join(DATA_DIR, "Clinical_Commissioning_Groups_(April_2019)_Names_and_Codes_in_England.csv"))
ccg_20 = pd.read_csv(os.path.join(DATA_DIR, "Clinical_Commissioning_Groups_(April_2020)_Names_and_Codes_in_England.csv"))

# %%
df = pd.read_csv(REFS_PATH)
df
# Out:
#                            Week CCG_Code  \
# 0       07/10/2019 - 13/10/2019      00C
# 1       07/10/2019 - 13/10/2019      00C
# 2       07/10/2019 - 13/10/2019      00C
# 3       07/10/2019 - 13/10/2019      00C
# 4       07/10/2019 - 13/10/2019      00C
# ...                         ...      ...
# 728918  21/12/2020 - 27/12/2020      DMT
# 728919  21/12/2020 - 27/12/2020      DR3
# 728920  21/12/2020 - 27/12/2020      DR3
# 728921  21/12/2020 - 27/12/2020      DR3
# 728922  21/12/2020 - 27/12/2020      DR3
#
#                                        CCG_Name     Priority    Specialty  \
# 0                            NHS DARLINGTON CCG  2 Week Wait          2WW
# 1                            NHS DARLINGTON CCG  2 Week Wait          2WW
# 2                            NHS DARLINGTON CCG  2 Week Wait          2WW
# 3                            NHS DARLINGTON CCG  2 Week Wait          2WW
# 4                            NHS DARLINGTON CCG  2 Week Wait          2WW
# ...                                         ...          ...          ...
# 728918                         FEDBUCKS LIMITED       Urgent  Gynaecology
# 728919  COASTAL HEALTH GP PROVIDER ORGANISATION  2 Week Wait          2WW
# 728920  COASTAL HEALTH GP PROVIDER ORGANISATION  2 Week Wait          2WW
# 728921  COASTAL HEALTH GP PROVIDER ORGANISATION  2 Week Wait          2WW
# 728922  COASTAL HEALTH GP PROVIDER ORGANISATION      Routine  Haematology
#
#               Clinic_Type  Referrals
# 0              2WW Breast         10
# 1         2WW Gynaecology          8
# 2         2WW Haematology          1
# 3       2WW Head and Neck          2
# 4            2WW Lower GI         22
# ...                   ...        ...
# 728918       Other_clinic          1
# 728919         2WW Breast          1
# 728920           2WW Skin          1
# 728921        2WW Urology          1
# 728922       Other_clinic          1
#
# [728923 rows x 7 columns]

# %% [markdown]
# ### Rename columns

# %%
rename_dict = dict(zip(df.columns, [col.lower() for col in df.columns]))
df = df.rename(columns=rename_dict)
df
# Out:
#                            week ccg_code  \
# 0       07/10/2019 - 13/10/2019      00C
# 1       07/10/2019 - 13/10/2019      00C
# 2       07/10/2019 - 13/10/2019      00C
# 3       07/10/2019 - 13/10/2019      00C
# 4       07/10/2019 - 13/10/2019      00C
# ...                         ...      ...
# 728918  21/12/2020 - 27/12/2020      DMT
# 728919  21/12/2020 - 27/12/2020      DR3
# 728920  21/12/2020 - 27/12/2020      DR3
# 728921  21/12/2020 - 27/12/2020      DR3
# 728922  21/12/2020 - 27/12/2020      DR3
#
#                                        ccg_name     priority    specialty  \
# 0                            NHS DARLINGTON CCG  2 Week Wait          2WW
# 1                            NHS DARLINGTON CCG  2 Week Wait          2WW
# 2                            NHS DARLINGTON CCG  2 Week Wait          2WW
# 3                            NHS DARLINGTON CCG  2 Week Wait          2WW
# 4                            NHS DARLINGTON CCG  2 Week Wait          2WW
# ...                                         ...          ...          ...
# 728918                         FEDBUCKS LIMITED       Urgent  Gynaecology
# 728919  COASTAL HEALTH GP PROVIDER ORGANISATION  2 Week Wait          2WW
# 728920  COASTAL HEALTH GP PROVIDER ORGANISATION  2 Week Wait          2WW
# 728921  COASTAL HEALTH GP PROVIDER ORGANISATION  2 Week Wait          2WW
# 728922  COASTAL HEALTH GP PROVIDER ORGANISATION      Routine  Haematology
#
#               clinic_type  referrals
# 0              2WW Breast         10
# 1         2WW Gynaecology          8
# 2         2WW Haematology          1
# 3       2WW Head and Neck          2
# 4            2WW Lower GI         22
# ...                   ...        ...
# 728918       Other_clinic          1
# 728919         2WW Breast          1
# 728920           2WW Skin          1
# 728921        2WW Urology          1
# 728922       Other_clinic          1
#
# [728923 rows x 7 columns]

# %%
df['ccg_code'].nunique()
# Out:
# 341

# %% [markdown]
# ### Reformat dates

# %%
df[['week_start', 'week_end']] = df['week'].str.split(' - ', expand=True)
df.drop(columns=['week', 'week_end'], inplace=True)
df['week_start'] = pd.to_datetime(df['week_start'], dayfirst=True)
df
# Out:
#        ccg_code                                 ccg_name     priority  \
# 0           00C                       NHS DARLINGTON CCG  2 Week Wait
# 1           00C                       NHS DARLINGTON CCG  2 Week Wait
# 2           00C                       NHS DARLINGTON CCG  2 Week Wait
# 3           00C                       NHS DARLINGTON CCG  2 Week Wait
# 4           00C                       NHS DARLINGTON CCG  2 Week Wait
# ...         ...                                      ...          ...
# 728918      DMT                         FEDBUCKS LIMITED       Urgent
# 728919      DR3  COASTAL HEALTH GP PROVIDER ORGANISATION  2 Week Wait
# 728920      DR3  COASTAL HEALTH GP PROVIDER ORGANISATION  2 Week Wait
# 728921      DR3  COASTAL HEALTH GP PROVIDER ORGANISATION  2 Week Wait
# 728922      DR3  COASTAL HEALTH GP PROVIDER ORGANISATION      Routine
#
#           specialty        clinic_type  referrals week_start
# 0               2WW         2WW Breast         10 2019-10-07
# 1               2WW    2WW Gynaecology          8 2019-10-07
# 2               2WW    2WW Haematology          1 2019-10-07
# 3               2WW  2WW Head and Neck          2 2019-10-07
# 4               2WW       2WW Lower GI         22 2019-10-07
# ...             ...                ...        ...        ...
# 728918  Gynaecology       Other_clinic          1 2020-12-21
# 728919          2WW         2WW Breast          1 2020-12-21
# 728920          2WW           2WW Skin          1 2020-12-21
# 728921          2WW        2WW Urology          1 2020-12-21
# 728922  Haematology       Other_clinic          1 2020-12-21
#
# [728923 rows x 7 columns]

# %%
# confirm no dups
df.shape, df.drop_duplicates().shape
# Out:
# ((728923, 7), (728923, 7))

# %% [markdown]
# ### Remove organisations other than CCGs

# %%
ccg_codes = sorted(list(set(ccg_20['CCG20CDH']) | set(ccg_19['CCG19CDH']))) # all ccg codes I'd expect to be in referrals table
df = df[df['ccg_code'].isin(ccg_codes)]  # excluding non-ccgs
df
# Out:
#        ccg_code             ccg_name     priority  \
# 0           00C   NHS DARLINGTON CCG  2 Week Wait
# 1           00C   NHS DARLINGTON CCG  2 Week Wait
# 2           00C   NHS DARLINGTON CCG  2 Week Wait
# 3           00C   NHS DARLINGTON CCG  2 Week Wait
# 4           00C   NHS DARLINGTON CCG  2 Week Wait
# ...         ...                  ...          ...
# 728529      97R  NHS EAST SUSSEX CCG       Urgent
# 728530      97R  NHS EAST SUSSEX CCG       Urgent
# 728531      97R  NHS EAST SUSSEX CCG       Urgent
# 728532      97R  NHS EAST SUSSEX CCG       Urgent
# 728533      97R  NHS EAST SUSSEX CCG       Urgent
#
#                                 specialty        clinic_type  referrals  \
# 0                                     2WW         2WW Breast         10
# 1                                     2WW    2WW Gynaecology          8
# 2                                     2WW    2WW Haematology          1
# 3                                     2WW  2WW Head and Neck          2
# 4                                     2WW       2WW Lower GI         22
# ...                                   ...                ...        ...
# 728529                     Sleep Medicine       Other_clinic          1
# 728530  Surgery - Not Otherwise Specified       Other_clinic          4
# 728531                 Surgery - Vascular       Other_clinic          6
# 728532                            Urology       Other_clinic         15
# 728533                            (blank)       Other_clinic          1
#
#        week_start
# 0      2019-10-07
# 1      2019-10-07
# 2      2019-10-07
# 3      2019-10-07
# 4      2019-10-07
# ...           ...
# 728529 2020-12-21
# 728530 2020-12-21
# 728531 2020-12-21
# 728532 2020-12-21
# 728533 2020-12-21
#
# [696708 rows x 7 columns]

# %% [markdown]
# ### Allow for CCG mergers

# %%
df = pd.merge(df, ccg_mergers, how='left', left_on='ccg_code', right_on='CCG19CDH')
df
# Out:
#        ccg_code             ccg_name     priority  \
# 0           00C   NHS DARLINGTON CCG  2 Week Wait
# 1           00C   NHS DARLINGTON CCG  2 Week Wait
# 2           00C   NHS DARLINGTON CCG  2 Week Wait
# 3           00C   NHS DARLINGTON CCG  2 Week Wait
# 4           00C   NHS DARLINGTON CCG  2 Week Wait
# ...         ...                  ...          ...
# 696703      97R  NHS EAST SUSSEX CCG       Urgent
# 696704      97R  NHS EAST SUSSEX CCG       Urgent
# 696705      97R  NHS EAST SUSSEX CCG       Urgent
# 696706      97R  NHS EAST SUSSEX CCG       Urgent
# 696707      97R  NHS EAST SUSSEX CCG       Urgent
#
#                                 specialty        clinic_type  referrals  \
# 0                                     2WW         2WW Breast         10
# 1                                     2WW    2WW Gynaecology          8
# 2                                     2WW    2WW Haematology          1
# 3                                     2WW  2WW Head and Neck          2
# 4                                     2WW       2WW Lower GI         22
# ...                                   ...                ...        ...
# 696703                     Sleep Medicine       Other_clinic          1
# 696704  Surgery - Not Otherwise Specified       Other_clinic          4
# 696705                 Surgery - Vascular       Other_clinic          6
# 696706                            Urology       Other_clinic         15
# 696707                            (blank)       Other_clinic          1
#
#        week_start CCG19CDH CCG20CDH
# 0      2019-10-07      00C      16C
# 1      2019-10-07      00C      16C
# 2      2019-10-07      00C      16C
# 3      2019-10-07      00C      16C
# 4      2019-10-07      00C      16C
# ...           ...      ...      ...
# 696703 2020-12-21      NaN      NaN
# 696704 2020-12-21      NaN      NaN
# 696705 2020-12-21      NaN      NaN
# 696706 2020-12-21      NaN      NaN
# 696707 2020-12-21      NaN      NaN
#
# [696708 rows x 9 columns]

# %%
# ccgs that did not merge kept the same id as before
df['CCG20CDH'] = df['CCG20CDH'].fillna(df['ccg_code'])
df = df.drop(columns=['ccg_code', 'CCG19CDH'])
df = df.rename(columns={'CCG20CDH': 'ccg_code'})
df
# Out:
#                    ccg_name     priority                          specialty  \
# 0        NHS DARLINGTON CCG  2 Week Wait                                2WW
# 1        NHS DARLINGTON CCG  2 Week Wait                                2WW
# 2        NHS DARLINGTON CCG  2 Week Wait                                2WW
# 3        NHS DARLINGTON CCG  2 Week Wait                                2WW
# 4        NHS DARLINGTON CCG  2 Week Wait                                2WW
# ...                     ...          ...                                ...
# 696703  NHS EAST SUSSEX CCG       Urgent                     Sleep Medicine
# 696704  NHS EAST SUSSEX CCG       Urgent  Surgery - Not Otherwise Specified
# 696705  NHS EAST SUSSEX CCG       Urgent                 Surgery - Vascular
# 696706  NHS EAST SUSSEX CCG       Urgent                            Urology
# 696707  NHS EAST SUSSEX CCG       Urgent                            (blank)
#
#               clinic_type  referrals week_start ccg_code
# 0              2WW Breast         10 2019-10-07      16C
# 1         2WW Gynaecology          8 2019-10-07      16C
# 2         2WW Haematology          1 2019-10-07      16C
# 3       2WW Head and Neck          2 2019-10-07      16C
# 4            2WW Lower GI         22 2019-10-07      16C
# ...                   ...        ...        ...      ...
# 696703       Other_clinic          1 2020-12-21      97R
# 696704       Other_clinic          4 2020-12-21      97R
# 696705       Other_clinic          6 2020-12-21      97R
# 696706       Other_clinic         15 2020-12-21      97R
# 696707       Other_clinic          1 2020-12-21      97R
#
# [696708 rows x 7 columns]

# %%
df['ccg_code'].nunique()
# Out:
# 135

# %% [markdown]
# ### Eliminate clinic_type

# %%
df = df.groupby(['week_start', 'ccg_code', 'ccg_name', 'specialty', 'priority'])['referrals'].sum().reset_index()
df
# Out:
#        week_start ccg_code                                  ccg_name  \
# 0      2019-10-07      00L                    NHS NORTHUMBERLAND CCG
# 1      2019-10-07      00L                    NHS NORTHUMBERLAND CCG
# 2      2019-10-07      00L                    NHS NORTHUMBERLAND CCG
# 3      2019-10-07      00L                    NHS NORTHUMBERLAND CCG
# 4      2019-10-07      00L                    NHS NORTHUMBERLAND CCG
# ...           ...      ...                                       ...
# 592679 2020-12-21      99M  NHS NORTH EAST HAMPSHIRE AND FARNHAM CCG
# 592680 2020-12-21      99M  NHS NORTH EAST HAMPSHIRE AND FARNHAM CCG
# 592681 2020-12-21      99M  NHS NORTH EAST HAMPSHIRE AND FARNHAM CCG
# 592682 2020-12-21      99M  NHS NORTH EAST HAMPSHIRE AND FARNHAM CCG
# 592683 2020-12-21      99M  NHS NORTH EAST HAMPSHIRE AND FARNHAM CCG
#
#                                 specialty     priority  referrals
# 0                                 (blank)      Routine         13
# 1                                 (blank)       Urgent          1
# 2                                     2WW  2 Week Wait        349
# 3                                 Allergy      Routine          3
# 4                              Cardiology      Routine         84
# ...                                   ...          ...        ...
# 592679  Surgery - Not Otherwise Specified       Urgent          2
# 592680                 Surgery - Vascular      Routine          2
# 592681                 Surgery - Vascular       Urgent          2
# 592682                            Urology      Routine         25
# 592683                            Urology       Urgent         11
#
# [592684 rows x 6 columns]

# %% [markdown]
# ### Remove ccg_name

# %%
df = df.drop(columns=['ccg_name'])
df
# Out:
#        week_start ccg_code                          specialty     priority  \
# 0      2019-10-07      00L                            (blank)      Routine
# 1      2019-10-07      00L                            (blank)       Urgent
# 2      2019-10-07      00L                                2WW  2 Week Wait
# 3      2019-10-07      00L                            Allergy      Routine
# 4      2019-10-07      00L                         Cardiology      Routine
# ...           ...      ...                                ...          ...
# 592679 2020-12-21      99M  Surgery - Not Otherwise Specified       Urgent
# 592680 2020-12-21      99M                 Surgery - Vascular      Routine
# 592681 2020-12-21      99M                 Surgery - Vascular       Urgent
# 592682 2020-12-21      99M                            Urology      Routine
# 592683 2020-12-21      99M                            Urology       Urgent
#
#         referrals
# 0              13
# 1               1
# 2             349
# 3               3
# 4              84
# ...           ...
# 592679          2
# 592680          2
# 592681          2
# 592682         25
# 592683         11
#
# [592684 rows x 5 columns]

# %% [markdown]
# ### Save

# %%
df.to_csv(os.path.join(OUT_DIR, "data", "referrals_oct19_dec20.csv"), index=False)
